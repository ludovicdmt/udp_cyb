# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
21224619122
# Out:
# array([ 0.00000000e+00,  0.00000000e+00,  2.00000000e-01,  2.00000000e-01,
#         4.00000000e-01,  6.00000000e-01,  6.00000000e-01,  8.00000000e-01,
#         1.00000000e+00,  1.00000000e+00,  1.20000000e+00,  1.40000000e+00,
#         1.40000000e+00,  1.20000000e+00,  1.40000000e+00,  1.40000000e+00,
#         1.40000000e+00,  1.40000000e+00,  1.40000000e+00,  1.40000000e+00,
#         1.60000000e+00,  1.80000000e+00,  1.80000000e+00,  1.60000000e+00,
#         1.40000000e+00,  1.40000000e+00,  1.40000000e+00,  1.40000000e+00,
#         1.20000000e+00,  1.20000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.20000000e+00,  1.20000000e+00,  1.00000000e+00,  1.00000000e+00,
#         8.00000000e-01,  6.00000000e-01,  6.00000000e-01,  8.00000000e-01,
#         8.00000000e-01,  6.00000000e-01,  4.00000000e-01,  2.00000000e-01,
#         2.00000000e-01,  2.00000000e-01,  4.00000000e-01,  4.00000000e-01,
# ...

# %%
data = np.load('..\\trajectory_data.npy') 
r = data[:, 0]
theta = data[:, 1]

x = r * np.cos(theta)
y = r * np.sin(theta)

# %%
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Trajectories in Cartesian Coordinates')
plt.grid(True)
